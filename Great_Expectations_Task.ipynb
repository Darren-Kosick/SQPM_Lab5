# %% [markdown]
# <a href="https://colab.research.google.com/github/Darren-Kosick/SQPM_Lab5/blob/main/Great_Expectations_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Great Expectations Task

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Install Great Expectations Library

# %%
# !pip install great_expectations
# Out:
# Requirement already satisfied: great_expectations in /usr/local/lib/python3.12/dist-packages (1.15.2)
# Requirement already satisfied: altair<7.0.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (5.5.0)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (43.0.3)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (3.1.6)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (4.26.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (3.26.2)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (3.2.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from great_expectations) (26.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (2.2.2)
# Requirement already satisfied: pydantic>=1.10.7 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (2.12.3)
# Requirement already satisfied: pyparsing!=3.2.4,>=2.4 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (2.9.0.post0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (2.32.4)
# Requirement already satisfied: ruamel.yaml>=0.16 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (0.19.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (1.16.3)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (4.15.0)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.12/dist-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<7.0.0,>=5.0.0->great_expectations) (2.18.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.2->great_expectations) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3->great_expectations) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->great_expectations) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->great_expectations) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->great_expectations) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.5.1->great_expectations) (0.30.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->great_expectations) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->great_expectations) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.7->great_expectations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.7->great_expectations) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.7->great_expectations) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.1->great_expectations) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->great_expectations) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->great_expectations) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->great_expectations) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->great_expectations) (2026.2.25)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (3.0)

# %% [markdown]
# ##2. Import Necessary Libraries

# %%
import pandas as pd
import great_expectations as gx

# %% [markdown]
# ##3. Load Labels.csv

# %% [markdown]
# Download and upload the [Labels.csv](https://github.com/zubxxr/SOFE3980U-Lab5/blob/main/Labels.csv) into this notebook, and then load the file.

# %%
df = pd.read_csv('/content/drive/MyDrive/SQPM Lab5/Labels.csv')
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ##4. Preview the Dataset

# %%
df.head()
# Out:
#     Timestamp  Car1_Location_X  Car1_Location_Y  Car1_Location_Z  \
# 0  1736796157       -51.402977              143         0.596902
# 1  1736796167       -53.819637              143         0.596902
# 2  1736796178       -50.239144              143         0.596902
# 3  1736796188       -53.707220              143         0.596902
# 4  1736796198       -52.053721              143         0.596902
#
#    Car2_Location_X  Car2_Location_Y  Car2_Location_Z Occluded_Image_view  \
# 0       -59.320270              140         0.596902           A_001.png
# 1       -59.196568              140         0.596902           A_002.png
# 2       -56.744479              140         0.596902           A_003.png
# 3       -57.309380              140         0.596902           A_004.png
# 4       -59.545897              140         0.596902           A_005.png
#
#   Occluding_Car_view Ground_Truth_View  pedestrianLocationX_TopLeft  \
# 0          B_001.png         C_001.png                          593
# 1          B_002.png         C_002.png                          579
# 2          B_003.png         C_003.png                          854
# 3          B_004.png         C_004.png                          549
# 4          B_005.png         C_005.png                          524
#
#    pedestrianLocationY_TopLeft  pedestrianLocationX_BottomRight  \
# 0                          361                              610
# 1                          368                              594
# 2                          720                              854
# 3                          368                              567
# 4                          368                              537
#
#    pedestrianLocationY_BottomRight
# 0                              410
# 1                              415
# 2                              720
# 3                              425
# 4                              413
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ##5. Set Up Great Expectations Context and Data Source

# %%
context = gx.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmplcwrd53s' for ephemeral docs site

# %% [markdown]
# ##6. Define and Create a Data Batch

# %%
batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": df})
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ##7. Define Three Expectations for Column Values

# %% [markdown]
# Using this [link](https://greatexpectations.io/expectations/), choose three expectation functions and apply them to the labels dataset in a relevant manner.
#
# You should replace the 'ExpectColumnValuesToBeBetween' function with other functions you select from the link.
#
# You can also check the format/parameters required of each function when you click "See more" on the function.

# %%
## Original Function
expectation = gx.expectations.ExpectColumnValuesToBeBetween(
    column="column", min_value=0, max_value=20
)

## Example Function

## This function only requires a column parameter, and not a max or min value
expectation = gx.expectations.ExpectColumnValuesToBeUnique(
    column="column"
)

# %% [markdown]
# ### Expectation 1

# %%
# Expectation 1: Ensure no null values in the Timestamp column
expectation1 = gx.expectations.ExpectColumnValuesToNotBeNull(
    column="Timestamp"
)

# %% [markdown]
# ### Validate Data Against Expectation 1

# %%
validation_result1 = batch.validate(expectation1)
print(validation_result1)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "Timestamp"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import nbformat
import os

# Get the current notebook path. In Colab, you can usually infer this.
# This assumes the notebook is saved and you are running it from its saved location.
# If you are in an unsaved notebook, you might need to adjust the path.
notebook_path = '/content/drive/MyDrive/SQPM Lab5/Great_Expectations_Task.ipynb' # Replace with your notebook's actual path if different

# Load the notebook
with open(notebook_path, 'r') as f:
    notebook_content = nbformat.read(f, as_version=4)

# Iterate through cells and remove 'widgets' from metadata if it exists
for cell in notebook_content.cells:
    if 'metadata' in cell and 'widgets' in cell['metadata']:
        del cell['metadata']['widgets']

# Save the modified notebook
with open(notebook_path, 'w') as f:
    nbformat.write(notebook_content, f)

print(f"Cleaned notebook saved to: {notebook_path}")
# Out:
# Cleaned notebook saved to: /content/drive/MyDrive/SQPM Lab5/Great_Expectations_Task.ipynb

# %% [markdown]
# After running the above cell, please save your notebook (`File > Save` or `Ctrl+S`) and then try pushing it to GitHub again. This should resolve the 'Invalid Notebook' error.

# %% [markdown]
# ### Expectation 2

# %%
# Expectation 2: Ensure pedestrian bounding box X coordinates are within valid image bounds (0 to 854)
expectation2 = gx.expectations.ExpectColumnValuesToBeBetween(
    column="pedestrianLocationX_TopLeft", min_value=0, max_value=854
)

# %% [markdown]
# ### Validate Data Against Expectation 2

# %%
validation_result2 = batch.validate(expectation2)
print(validation_result2)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "pedestrianLocationX_TopLeft",
#       "min_value": 0.0,
#       "max_value": 854.0
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ### Expectation 3

# %%
# Expectation 3: Ensure each Timestamp is unique (no duplicate entries)
expectation3 = gx.expectations.ExpectColumnValuesToBeUnique(
    column="Timestamp"
)

# %% [markdown]
# ### Validate Data Against Expectation 3

# %%
validation_result3 = batch.validate(expectation3)
print(validation_result3)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "Timestamp"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
